# %%
# !pip install transformers
# Out:
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (d:\projects\hackathons\ai4d asr challenge\env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\projects\hackathons\ai4d asr challenge\env\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (d:\projects\hackathons\ai4d asr challenge\env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\projects\hackathons\ai4d asr challenge\env\lib\site-packages)

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("automatic-speech-recognition", model="Akashpb13/Swahili_xlsr")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from glob import glob
import pandas as pd
from tqdm import tqdm

# %%
test = pd.read_csv('data/test.csv')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install ffmpeg-python
# Out:
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (d:\projects\hackathons\ai4d asr challenge\env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\projects\hackathons\ai4d asr challenge\env\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (d:\projects\hackathons\ai4d asr challenge\env\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\projects\hackathons\ai4d asr challenge\env\lib\site-packages)

# %%
res = []
for path in tqdm(test.path):
    res.append(pipe(f'data/audio_files/test_audios/{path}')['text'])
# Out:
#   0%|          | 0/3167 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File d:\Projects\Hackathons\AI4D ASR Challenge\env\lib\site-packages\transformers\pipelines\audio_utils.py:34, in ffmpeg_read(bpayload, sampling_rate)
#      33 try:
# ---> 34     with subprocess.Popen(ffmpeg_command, stdin=subprocess.PIPE, stdout=subprocess.PIPE) as ffmpeg_process:
#      35         output_stream = ffmpeg_process.communicate(bpayload)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     948             self.stderr = io.TextIOWrapper(self.stderr,
# ...

# %%
test['sentence'] = res

# %%
test[['audio_ID', 'sentence']].to_csv('submission5.csv', index=False)

# %%
test
# Out:
#             audio_ID                path  \
# 0     audio_3c2f423a  audio_3c2f423a.mp3
# 1     audio_ca8009ec  audio_ca8009ec.mp3
# 2     audio_fffcdb86  audio_fffcdb86.mp3
# 3     audio_0e3e8e6f  audio_0e3e8e6f.mp3
# 4     audio_859b792d  audio_859b792d.mp3
# ...              ...                 ...
# 3162  audio_bdc72517  audio_bdc72517.mp3
# 3163  audio_50ee5991  audio_50ee5991.mp3
# 3164  audio_b9867662  audio_b9867662.mp3
# 3165  audio_a0739877  audio_a0739877.mp3
# 3166  audio_ae65cf8a  audio_ae65cf8a.mp3
#
#                                                sentence
# 0                                            chuza vema
# 1           ninne watoto wakikuti na ujamii meyao kabia
# 2                                   biashara ni biashan
# 3                      hachofu libiki ibiisha la mwisho
# 4     ni kama hapa ukimwambia mtu twenda kuvaua hata...
# ...                                                 ...
# 3162                 mtu muhimu sana ndio mama uchaguzi
# ...

# %%
# !pip install huggingsound
# Out:
# ...
#   Obtaining dependency information for datasets<3.0.0,>=2.6.1 from https://files.pythonhosted.org/packages/66/f8/38298237d18d4b6a8ee5dfe390e97bed5adb8e01ec6f9680c0ddf3066728/datasets-2.14.4-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/214.3 kB ? eta -:--:--
#      ----------- --------------------------- 61.4/214.3 kB 1.1 MB/s eta 0:00:01
#      ----------- --------------------------- 61.4/214.3 kB 1.1 MB/s eta 0:00:01
#      ----------- --------------------------- 61.4/214.3 kB 1.1 MB/s eta 0:00:01
#      ----------- --------------------------- 61.4/214.3 kB 1.1 MB/s eta 0:00:01
#      ------------------ ----------------- 112.6/214.3 kB 409.6 kB/s eta 0:00:01
#      ------------------ ----------------- 112.6/214.3 kB 409.6 kB/s eta 0:00:01
#      ----------------------------- ------ 174.1/214.3 kB 498.0 kB/s eta 0:00:01
#      -------------------------------- --- 194.6/214.3 kB 512.0 kB/s eta 0:00:01
# ...
